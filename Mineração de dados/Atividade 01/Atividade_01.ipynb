# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('br_ibge_censo_2022_alfabetizacao_grupo_idade_sexo_raca.csv')

# %%
df.head()
# Out:
#    id_municipio  cor_raca      sexo   grupo_idade      alfabetizacao  \
# 0       1100023  Indígena    Homens  15 a 19 anos  Não alfabetizadas
# 1       1100262   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 2       1101005   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 3       1101435   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 4       1101435  Indígena  Mulheres  15 a 19 anos  Não alfabetizadas
#
#    populacao
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.tail()
# Out:
#         id_municipio cor_raca      sexo      grupo_idade  alfabetizacao  \
# 779795       2924009    Parda    Homens  65 anos ou mais  Alfabetizadas
# 779796       4318903   Branca  Mulheres  65 anos ou mais  Alfabetizadas
# 779797       4127700   Branca    Homens  65 anos ou mais  Alfabetizadas
# 779798       3302700   Branca  Mulheres  65 anos ou mais  Alfabetizadas
# 779799       2607901    Parda  Mulheres  65 anos ou mais  Alfabetizadas
#
#         populacao
# 779795     1791.0
# 779796     2047.0
# 779797     4351.0
# 779798     7167.0
# 779799    13823.0

# %%
df.isna().sum()
# Out:
# id_municipio          0
# cor_raca              0
# sexo                  0
# grupo_idade           0
# alfabetizacao         0
# populacao        250085
# dtype: int64

# %%
df[df.isna() == 'populacao']
# Out:
#         id_municipio cor_raca sexo grupo_idade alfabetizacao  populacao
# 0                NaN      NaN  NaN         NaN           NaN        NaN
# 1                NaN      NaN  NaN         NaN           NaN        NaN
# 2                NaN      NaN  NaN         NaN           NaN        NaN
# 3                NaN      NaN  NaN         NaN           NaN        NaN
# 4                NaN      NaN  NaN         NaN           NaN        NaN
# ...              ...      ...  ...         ...           ...        ...
# 779795           NaN      NaN  NaN         NaN           NaN        NaN
# 779796           NaN      NaN  NaN         NaN           NaN        NaN
# 779797           NaN      NaN  NaN         NaN           NaN        NaN
# 779798           NaN      NaN  NaN         NaN           NaN        NaN
# 779799           NaN      NaN  NaN         NaN           NaN        NaN
#
# [779800 rows x 6 columns]

# %%
imputer = SimpleImputer()

# %%
df[['populacao']].head()
# Out:
#    populacao
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
array_clear_data = imputer.fit_transform(df[['populacao']])

# %%
array_clear_data
# Out:
# array([[  307.60317152],
#        [  307.60317152],
#        [  307.60317152],
#        ...,
#        [ 4351.        ],
#        [ 7167.        ],
#        [13823.        ]])

# %%
df_clear_data = pd.DataFrame(data = array_clear_data, columns=imputer.get_feature_names_out())

# %%
df_clear_data.isna().sum()
# Out:
# populacao    0
# dtype: int64
