# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/br_rj_isp_estatisticas_seguranca_armas_apreendidas_mensal.csv')

# %%
df.head()
# Out:
#     ano  mes  id_cisp  id_aisp  id_risp  quantidade_arma_fabricacao_caseira  \
# 0  2007   10       10        2        1                                   0
# 1  2021    2      105       26        7                                   0
# 2  2013   10      105       26        7                                   0
# 3  2021    5      105       26        7                                   0
# 4  2021   12      106       26        7                                   0
#
#    quantidade_carabina  quantidade_espingarda  quantidade_fuzil  \
# 0                    0                      3                 7
# 1                    0                      3                 0
# 2                    1                      4                 0
# 3                    0                      0                 0
# 4                    4                      4                 0
#
#    quantidade_garrucha  quantidade_garruchao  quantidade_metralhadora  \
# 0                    1                     0                        3
# 1                    7                     8                        0
# 2                    2                     0                        0
# 3                    9                     0                        0
# 4                    0                     0                        0
#
#    quantidade_outros  quantidade_pistola  quantidade_revolver  \
# 0                  0                  12                    6
# 1                  0                   9                   11
# 2                  2                   5                    7
# 3                  0                   4                    9
# 4                  0                   7                    6
#
#    quantidade_submetralhadora  total
# 0                           0     32
# 1                           0     38
# 2                           0     21
# 3                           0     22
# 4                           0     21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31380 entries, 0 to 31379
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ano                                 31380 non-null  int64
#  1   mes                                 31380 non-null  int64
#  2   id_cisp                             31380 non-null  int64
#  3   id_aisp                             31380 non-null  int64
#  4   id_risp                             31380 non-null  int64
#  5   quantidade_arma_fabricacao_caseira  31380 non-null  int64
#  6   quantidade_carabina                 31380 non-null  int64
#  7   quantidade_espingarda               31380 non-null  int64
#  8   quantidade_fuzil                    31380 non-null  int64
#  9   quantidade_garrucha                 31380 non-null  int64
#  10  quantidade_garruchao                31380 non-null  int64
#  11  quantidade_metralhadora             31380 non-null  int64
#  12  quantidade_outros                   31380 non-null  int64
#  13  quantidade_pistola                  31380 non-null  int64
#  14  quantidade_revolver                 31380 non-null  int64
#  15  quantidade_submetralhadora          31380 non-null  int64
#  16  total                               31380 non-null  int64
# dtypes: int64(17)
# memory usage: 4.1 MB

# %%
df.isnull().sum()
# Out:
# ano                                   0
# mes                                   0
# id_cisp                               0
# id_aisp                               0
# id_risp                               0
# quantidade_arma_fabricacao_caseira    0
# quantidade_carabina                   0
# quantidade_espingarda                 0
# quantidade_fuzil                      0
# quantidade_garrucha                   0
# quantidade_garruchao                  0
# quantidade_metralhadora               0
# quantidade_outros                     0
# quantidade_pistola                    0
# quantidade_revolver                   0
# quantidade_submetralhadora            0
# total                                 0
# dtype: int64

# %%
df['data'] = df['ano'].astype(str) + '-' + df['mes'].astype(str).str.zfill(2) + '-01'

# %%
df.head()
# Out:
#     ano  mes  id_cisp  id_aisp  id_risp  quantidade_arma_fabricacao_caseira  \
# 0  2007   10       10        2        1                                   0
# 1  2021    2      105       26        7                                   0
# 2  2013   10      105       26        7                                   0
# 3  2021    5      105       26        7                                   0
# 4  2021   12      106       26        7                                   0
#
#    quantidade_carabina  quantidade_espingarda  quantidade_fuzil  \
# 0                    0                      3                 7
# 1                    0                      3                 0
# 2                    1                      4                 0
# 3                    0                      0                 0
# 4                    4                      4                 0
#
#    quantidade_garrucha  quantidade_garruchao  quantidade_metralhadora  \
# 0                    1                     0                        3
# 1                    7                     8                        0
# 2                    2                     0                        0
# 3                    9                     0                        0
# 4                    0                     0                        0
#
#    quantidade_outros  quantidade_pistola  quantidade_revolver  \
# 0                  0                  12                    6
# 1                  0                   9                   11
# 2                  2                   5                    7
# 3                  0                   4                    9
# 4                  0                   7                    6
#
#    quantidade_submetralhadora  total    data_str
# 0                           0     32  2007-10-01
# 1                           0     38  2021-02-01
# 2                           0     21  2013-10-01
# 3                           0     22  2021-05-01
# 4                           0     21  2021-12-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31380 entries, 0 to 31379
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ano                                 31380 non-null  int64
#  1   mes                                 31380 non-null  int64
#  2   id_cisp                             31380 non-null  int64
#  3   id_aisp                             31380 non-null  int64
#  4   id_risp                             31380 non-null  int64
#  5   quantidade_arma_fabricacao_caseira  31380 non-null  int64
#  6   quantidade_carabina                 31380 non-null  int64
#  7   quantidade_espingarda               31380 non-null  int64
#  8   quantidade_fuzil                    31380 non-null  int64
#  9   quantidade_garrucha                 31380 non-null  int64
#  10  quantidade_garruchao                31380 non-null  int64
#  11  quantidade_metralhadora             31380 non-null  int64
#  12  quantidade_outros                   31380 non-null  int64
#  13  quantidade_pistola                  31380 non-null  int64
#  14  quantidade_revolver                 31380 non-null  int64
#  15  quantidade_submetralhadora          31380 non-null  int64
#  16  total                               31380 non-null  int64
#  17  data_str                            31380 non-null  object
# dtypes: int64(17), object(1)
# memory usage: 4.3+ MB

# %%
df['data'] = pd.to_datetime(df['data_str'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31380 entries, 0 to 31379
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ano                                 31380 non-null  int64
#  1   mes                                 31380 non-null  int64
#  2   id_cisp                             31380 non-null  int64
#  3   id_aisp                             31380 non-null  int64
#  4   id_risp                             31380 non-null  int64
#  5   quantidade_arma_fabricacao_caseira  31380 non-null  int64
#  6   quantidade_carabina                 31380 non-null  int64
#  7   quantidade_espingarda               31380 non-null  int64
#  8   quantidade_fuzil                    31380 non-null  int64
#  9   quantidade_garrucha                 31380 non-null  int64
#  10  quantidade_garruchao                31380 non-null  int64
#  11  quantidade_metralhadora             31380 non-null  int64
#  12  quantidade_outros                   31380 non-null  int64
#  13  quantidade_pistola                  31380 non-null  int64
#  14  quantidade_revolver                 31380 non-null  int64
#  15  quantidade_submetralhadora          31380 non-null  int64
#  16  total                               31380 non-null  int64
#  17  data_str                            31380 non-null  object
#  18  data                                31380 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(17), object(1)
# memory usage: 4.5+ MB

# %%
df.drop(columns=['data_str'], inplace=True)

# %%
df['total'].describe()
# Out:
# count    31380.000000
# mean         4.637094
# std          5.941119
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max        201.000000
# Name: total, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31380 entries, 0 to 31379
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ano                                 31380 non-null  int64
#  1   mes                                 31380 non-null  int64
#  2   id_cisp                             31380 non-null  int64
#  3   id_aisp                             31380 non-null  int64
#  4   id_risp                             31380 non-null  int64
#  5   quantidade_arma_fabricacao_caseira  31380 non-null  int64
#  6   quantidade_carabina                 31380 non-null  int64
#  7   quantidade_espingarda               31380 non-null  int64
#  8   quantidade_fuzil                    31380 non-null  int64
#  9   quantidade_garrucha                 31380 non-null  int64
#  10  quantidade_garruchao                31380 non-null  int64
#  11  quantidade_metralhadora             31380 non-null  int64
#  12  quantidade_outros                   31380 non-null  int64
#  13  quantidade_pistola                  31380 non-null  int64
#  14  quantidade_revolver                 31380 non-null  int64
#  15  quantidade_submetralhadora          31380 non-null  int64
#  16  total                               31380 non-null  int64
#  17  data                                31380 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(17)
# memory usage: 4.3 MB

# %%
df.shape
# Out:
# (31380, 18)

# %%
df['total'].mean()
# Out:
# np.float64(4.637093690248566)

# %%
df['total'].median()
# Out:
# 3.0

# %%
df['total'].mode()
# Out:
# 0    0
# Name: total, dtype: int64

# %%
df_total_armas_por_ano = df.groupby('ano')['total'].sum().reset_index()

# %%
# Out:
#     ano  total
# 0  2007  11062
# 1  2008   9533
# 2  2009   8914
# 3  2010   7601
# 4  2011   7435

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='ano', y='total', data=df_total_armas_por_ano, palette='viridis')
plt.title('Total de Armas Apreendidas por Ano')
plt.xlabel('Ano')
plt.ylabel('Número Total de Armas Apreendidas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-49d2c170a098>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='ano', y='total', data=df_total_armas_por_ano, palette='viridis')

# %%
colunas_armas_quantidade = [
     'quantidade_arma_fabricacao_caseira', 'quantidade_garrucha', 'quantidade_espingarda',
     'quantidade_carabina', 'quantidade_fuzil', 'quantidade_metralhadora',
     'quantidade_pistola', 'quantidade_revolver', 'quantidade_submetralhadora',
     'quantidade_outros'
 ]

# %%
colunas_armas_quantidade.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-10fb02a27355> in <cell line: 0>()
# ----> 1 colunas_armas_quantidade.head()
#
# AttributeError: 'list' object has no attribute 'head'
